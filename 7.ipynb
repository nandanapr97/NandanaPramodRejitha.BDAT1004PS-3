# %% [markdown]
# #Question 7

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
url = 'https://raw.githubusercontent.com/nandanapr97/NandanaPramodRejitha.BDAT1004PS-3/main/us-marriages-divorces-1867-2014.csv'
data = pd.read_csv(url)
data
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
# Filter data for the years 1900, 1950, and 2000
years_1900_1950_2000 = data[data['Year'].isin([1900, 1950, 2000])]
years_1900_1950_2000
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 33   1900   709000.0   56000.0    76094000                 9.3
# 83   1950  1667000.0  385000.0   151684000                11.0
# 133  2000  2315000.0  944000.0   282398000                 8.2
#
#      Divorces_per_1000
# 33                 0.7
# 83                 2.5
# 133                3.3

# %%
# Create a bar chart
plt.figure(figsize=(10, 6))
bar_width = 10

# Plot marriages
plt.bar(years_1900_1950_2000['Year'] - bar_width/2, selected_years['Marriages_per_1000'],
        width=bar_width, label='Marriages per Capita', align='center')

# Plot divorces
plt.bar(years_1900_1950_2000['Year'] + bar_width/2, selected_years['Divorces_per_1000'],
        width=bar_width, label='Divorces per Capita', align='center')

# Labeling and legend
plt.title('Number of Marriages and Divorces per Capita in the U.S. (1900, 1950, 2000)')
plt.xlabel('Year')
plt.ylabel('Number per 1000 People')
plt.xticks(years_1900_1950_2000['Year'], ['1900', '1950', '2000'])
plt.legend()

# Show the plot
plt.show()
